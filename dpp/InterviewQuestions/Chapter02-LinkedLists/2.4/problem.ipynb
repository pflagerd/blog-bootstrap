# %%
files = !ls -la
print(files)
# Out:
# ['total 124', 'drwxrwxr-x 6 oy753c oy753c  4096 Aug 24 09:43 .', 'drwxrwxr-x 7 oy753c oy753c  4096 Aug 24 08:27 ..', '-rw-rw-r-- 1 oy753c oy753c   413 Jul 29 09:14 .dirinfo', 'drwxrwxr-x 3 oy753c oy753c  4096 Aug 24 09:35 .idea', 'drwxrwxr-x 2 oy753c oy753c  4096 Aug 24 09:43 .ipynb_checkpoints', 'drwxrwxr-x 7 oy753c oy753c  4096 Aug 24 09:17 .venv', '-rwxrwxr-x 1 oy753c oy753c   144 Jul 29 09:14 RUNME', '-rwxrwxr-x 1 oy753c oy753c   109 Jul 29 09:14 SETMEUP', '-rw-rw-r-- 1 oy753c oy753c   858 Jul 29 09:14 generate_json_test_cases.py', '-rw-rw-r-- 1 oy753c oy753c   722 Jul 29 09:14 generate_python_test_cases.py', 'drwxrwxr-x 2 oy753c oy753c  4096 Aug 24 08:27 html', '-rw-rw-r-- 1 oy753c oy753c 26151 Aug 19 09:22 problem-solving-procedure.html', '-rw-rw-r-- 1 oy753c oy753c  3807 Jul 29 09:14 problem.html', '-rw-rw-r-- 1 oy753c oy753c   617 Aug 24 09:39 problem.ipynb', '-rw-rw-r-- 1 oy753c oy753c  1668 Aug 12 08:33 problem.json', '-rw-rw-r-- 1 oy753c oy753c 39232 Jul 29 09:58 problem.p
# ...
