# %%
ls
# Out:
# generate_json_test_cases.py    problem.ipynb                   __pycache__/
# generate_python_test_cases.py  problem.json                    RUNME*
# problem-2.ipynb                problem.py                      SETMEUP
# problem-djf.py                 problem-py.bck                  Untitled.ipynb
# problem.html                   problem-solving-procedure.html
